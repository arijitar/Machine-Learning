# %% [markdown]
# <a href="https://colab.research.google.com/github/arijitar/Machine-Learning/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
data = pd.Series([2, 3, 4, 5], index = ['a', 'b', 'c', 'd'])

# %%
data.values
# Out:
# array([2, 3, 4, 5])

# %%
data.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
print(pd.__version__)
# Out:
# 2.1.4

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data['a']
# Out:
# 2

# %%
data['a':'c']
# Out:
# a    2
# b    3
# c    4
# dtype: int64

# %%
grades = {'A':4, 'A-':3.5,'B':3,'B-':2.5, 'B':2}
grade = pd.Series(grades)

# %%
grade
# Out:
# A     4.0
# A-    3.5
# B     2.0
# B-    2.5
# dtype: float64

# %%
marks = {'A': 85, 'A-': 80, 'B':75, 'B-':70}
marks = pd.Series(marks)

# %%
marks
# Out:
# A     85
# A-    80
# B     75
# B-    70
# dtype: int64

# %%
marks['A']
# Out:
# 85

# %%
marks[0:2]
# Out:
# A     85
# A-    80
# dtype: int64

# %%
marks.index
# Out:
# Index(['A', 'A-', 'B', 'B-'], dtype='object')

# %% [markdown]
# # Data-Frames

# %%
df = pd.DataFrame(
    {
       " Name":["Braund,Mr. Owen Harris",
            "Allen,Mr. William Henry",
            "Bonnell,Miss. Elizabeth"],
        "Age": [22, 35, 54],
        "Sex": ["male", "male", "female"],
    }
)

# %%
df.T
# Out:
#                             0                        1  \
#  Name  Braund,Mr. Owen Harris  Allen,Mr. William Henry
# Age                        22                       35
# Sex                      male                     male
#
#                              2
#  Name  Bonnell,Miss. Elizabeth
# Age                         54
# Sex                     female

# %%
# Each column in a DataFrame is a Series
df.values
# Out:
# array([['Braund,Mr. Owen Harris', 22, 'male'],
#        ['Allen,Mr. William Henry', 35, 'male'],
#        ['Bonnell,Miss. Elizabeth', 54, 'female']], dtype=object)

# %%
df["Age"]
# Out:
# 0    22
# 1    35
# 2    54
# Name: Age, dtype: int64

# %%
df["Sex"]
# Out:
# 0      male
# 1      male
# 2    female
# Name: Sex, dtype: object

# %%
ages = pd.Series([22, 35, 45], name = "Age")

# %%
ages
# Out:
# 0    22
# 1    35
# 2    45
# Name: Age, dtype: int64

# %%
df
# Out:
#                        Name  Age     Sex
# 0   Braund, Mr. Owen Harris   22    male
# 1  Allen, Mr. William Henry   35    male
# 2  Bonnell, Miss. Elizabeth   44  female

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df = df)
# Out:
# https://docs.google.com/spreadsheets/d/1kidkFHico7S782NEYtgq8iTEUVSffdXAfktk-S2ro_U#gid=0
# /usr/local/lib/python3.10/dist-packages/google/colab/sheets.py:31: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   return frame.applymap(_clean_val).replace({np.nan: None})
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1kidkFHico7S782NEYtgq8iTEUVSffdXAfktk-S2ro_U#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df["Age"].max()
# Out:
# 54

# %%
ages.max()
# Out:
# 45

# %%
df.describe()
# Out:
#              Age
# count   3.000000
# mean   37.000000
# std    16.093477
# min    22.000000
# 25%    28.500000
# 50%    35.000000
# 75%    44.500000
# max    54.000000

# %%
import csv

# %%
df = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv")
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df.T
# Out:
#                      0               1                  2               3    \
# Name       Avery Bradley     Jae Crowder       John Holland     R.J. Hunter
# Team      Boston Celtics  Boston Celtics     Boston Celtics  Boston Celtics
# Number               0.0            99.0               30.0            28.0
# Position              PG              SF                 SG              SG
# Age                 25.0            25.0               27.0            22.0
# Height               6-2             6-6                6-5             6-5
# Weight             180.0           235.0              205.0           185.0
# College            Texas       Marquette  Boston University   Georgia State
# Salary         7730337.0       6796117.0                NaN       1148640.0
#
#                      4               5               6               7    \
# Name       Jonas Jerebko    Amir Johnson   Jordan Mickey    Kelly Olynyk
# ...

# %%
df[df['Number']>60]
# Out:
#                     Name                    Team  Number Position   Age  \
# 1            Jae Crowder          Boston Celtics    99.0       SF  25.0
# 5           Amir Johnson          Boston Celtics    90.0       PF  29.0
# 68        Lucas Nogueira         Toronto Raptors    92.0        C  23.0
# 222  Johnny O'Bryant III         Milwaukee Bucks    77.0       PF  23.0
# 372          Drew Gooden      Washington Wizards    90.0       PF  34.0
# 391    Joffrey Lauvergne          Denver Nuggets    77.0        C  24.0
# 398      Nemanja Bjelica  Minnesota Timberwolves    88.0       PF  28.0
#
#     Height  Weight    College      Salary
# 1      6-6   235.0  Marquette   6796117.0
# 5      6-9   240.0        NaN  12000000.0
# 68     7-0   220.0        NaN   1842000.0
# 222    6-9   257.0        LSU    845059.0
# 372   6-10   250.0     Kansas   3300000.0
# 391   6-11   220.0        NaN   1709719.0
# 398   6-10   240.0        NaN   3950001.0

# %%
df.tail(10)
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# ...

# %%
df.to_excel('nba.xlsx', sheet_name='nba_data')

# %%
df = pd.read_excel('nba.xlsx', sheet_name='nba_data')

# %%
df.head()
# Out:
#    Unnamed: 0           Name            Team  Number Position   Age Height  \
# 0           0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1           1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2           2   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3           3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4           4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
#
#    Weight            College     Salary
# 0   180.0              Texas  7730337.0
# 1   235.0          Marquette  6796117.0
# 2   205.0  Boston University        NaN
# 3   185.0      Georgia State  1148640.0
# 4   231.0                NaN  5000000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  458 non-null    int64
#  1   Name        457 non-null    object
#  2   Team        457 non-null    object
#  3   Number      457 non-null    float64
#  4   Position    457 non-null    object
#  5   Age         457 non-null    float64
#  6   Height      457 non-null    object
#  7   Weight      457 non-null    float64
#  8   College     373 non-null    object
#  9   Salary      446 non-null    float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 35.9+ KB

# %%
ages = df['Age']

# %%
ages.head(10)
# Out:
# 0    25.0
# 1    25.0
# 2    27.0
# 3    22.0
# 4    29.0
# 5    29.0
# 6    21.0
# 7    25.0
# 8    22.0
# 9    22.0
# Name: Age, dtype: float64

# %%
type(df['Age'])
# Out:
# pandas.core.series.Series

# %%
age_salary = df[['Age', 'Salary']]

# %%
age_salary.head(10)
# Out:
#     Age      Salary
# 0  25.0   7730337.0
# 1  25.0   6796117.0
# 2  27.0         NaN
# 3  22.0   1148640.0
# 4  29.0   5000000.0
# 5  29.0  12000000.0
# 6  21.0   1170960.0
# 7  25.0   2165160.0
# 8  22.0   1824360.0
# 9  22.0   3431040.0

# %%
df[['Age', 'Salary']].shape # Out: (Row, Column)
# Out:
# (458, 2)

# %%
A = pd.DataFrame([{'a':1,'b':4}, {'b': -3, 'c': 9}])
A
# Out:
#      a  b    c
# 0  1.0  4  NaN
# 1  NaN -3  9.0

# %%
A.fillna(0)
# Out:
#      a  b    c
# 0  1.0  4  0.0
# 1  0.0 -3  9.0

# %% [markdown]
# # Pandas(Indexing)

# %%
A = pd.Series(['a', 'b', 'c'], index = [1, 2, 3])
A
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
A[1]
# Out:
# 'a'

# %%
A[1:3]
# Out:
# 2    b
# 3    c
# dtype: object

# %%
A.loc[1:3] # use loc for explicit index
# Out:
# 1    a
# 2    b
# 3    c
# dtype: object

# %%
A.iloc[1:3] # use iloc for implicit index
# Out:
# 2    b
# 3    c
# dtype: object

# %%
df.iloc[2, :]
# Out:
# Unnamed: 0                    2
# Name               John Holland
# Team             Boston Celtics
# Number                     30.0
# Position                     SG
# Age                        27.0
# Height                      6-5
# Weight                    205.0
# College       Boston University
# Salary                      NaN
# Name: 2, dtype: object

# %%
df.iloc[::-1, :]
# Out:
#      Unnamed: 0           Name            Team  Number Position   Age Height  \
# 457         457            NaN             NaN     NaN      NaN   NaN    NaN
# 456         456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
# 455         455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 454         454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 453         453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# ..          ...            ...             ...     ...      ...   ...    ...
# 4             4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# 3             3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 2             2   John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 1             1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 0             0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
#
#      Weight            College     Salary
# ...

# %% [markdown]
# # Pandas( csv files)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d746ad95-1434-40a0-be7c-a5fadb246fd2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d746ad95-1434-40a0-be7c-a5fadb246fd2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
df = pd.read_csv('WHO-COVID-19-global-data.csv')
df.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan       EMRO        NaN
# 5    2020-02-09           AF  Afghanistan       EMRO        NaN
# 6    2020-02-16           AF  Afghanistan       EMRO        NaN
# 7    2020-02-23           AF  Afghanistan       EMRO        NaN
# 8    2020-03-01           AF  Afghanistan       EMRO        1.0
# 9    2020-03-08           AF  Afghanistan       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# ...

# %%
df.drop(['New_cases', 'New_deaths', 'Cumulative_deaths'], axis =1, inplace = True)

# %%
df.head(10)
# Out:
#   Date_reported Country_code      Country WHO_region  Cumulative_cases
# 0    2020-01-05           AF  Afghanistan       EMRO                 0
# 1    2020-01-12           AF  Afghanistan       EMRO                 0
# 2    2020-01-19           AF  Afghanistan       EMRO                 0
# 3    2020-01-26           AF  Afghanistan       EMRO                 0
# 4    2020-02-02           AF  Afghanistan       EMRO                 0
# 5    2020-02-09           AF  Afghanistan       EMRO                 0
# 6    2020-02-16           AF  Afghanistan       EMRO                 0
# 7    2020-02-23           AF  Afghanistan       EMRO                 0
# 8    2020-03-01           AF  Afghanistan       EMRO                 1
# 9    2020-03-08           AF  Afghanistan       EMRO                 1

# %%
df.rename(columns = {'Date_reported': 'Date','Country_code': 'Code', 'WHO_region': 'Region'}, inplace = True)

# %%
df.head(10)
# Out:
#          Date Code      Country Region  Cumulative_cases
# 0  2020-01-05   AF  Afghanistan   EMRO                 0
# 1  2020-01-12   AF  Afghanistan   EMRO                 0
# 2  2020-01-19   AF  Afghanistan   EMRO                 0
# 3  2020-01-26   AF  Afghanistan   EMRO                 0
# 4  2020-02-02   AF  Afghanistan   EMRO                 0
# 5  2020-02-09   AF  Afghanistan   EMRO                 0
# 6  2020-02-16   AF  Afghanistan   EMRO                 0
# 7  2020-02-23   AF  Afghanistan   EMRO                 0
# 8  2020-03-01   AF  Afghanistan   EMRO                 1
# 9  2020-03-08   AF  Afghanistan   EMRO                 1

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.head(10)
# Out:
#         Date Code      Country Region  Cumulative_cases
# 0 2020-01-05   AF  Afghanistan   EMRO                 0
# 1 2020-01-12   AF  Afghanistan   EMRO                 0
# 2 2020-01-19   AF  Afghanistan   EMRO                 0
# 3 2020-01-26   AF  Afghanistan   EMRO                 0
# 4 2020-02-02   AF  Afghanistan   EMRO                 0
# 5 2020-02-09   AF  Afghanistan   EMRO                 0
# 6 2020-02-16   AF  Afghanistan   EMRO                 0
# 7 2020-02-23   AF  Afghanistan   EMRO                 0
# 8 2020-03-01   AF  Afghanistan   EMRO                 1
# 9 2020-03-08   AF  Afghanistan   EMRO                 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57600 entries, 0 to 57599
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              57600 non-null  datetime64[ns]
#  1   Code              57360 non-null  object
#  2   Country           57600 non-null  object
#  3   Region            53280 non-null  object
#  4   Cumulative_cases  57600 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ MB

# %%
df.head(10)
# Out:
#         Date Code      Country Region  Cumulative_cases
# 0 2020-01-05   AF  Afghanistan   EMRO                 0
# 1 2020-01-12   AF  Afghanistan   EMRO                 0
# 2 2020-01-19   AF  Afghanistan   EMRO                 0
# 3 2020-01-26   AF  Afghanistan   EMRO                 0
# 4 2020-02-02   AF  Afghanistan   EMRO                 0
# 5 2020-02-09   AF  Afghanistan   EMRO                 0
# 6 2020-02-16   AF  Afghanistan   EMRO                 0
# 7 2020-02-23   AF  Afghanistan   EMRO                 0
# 8 2020-03-01   AF  Afghanistan   EMRO                 1
# 9 2020-03-08   AF  Afghanistan   EMRO                 1

# %%
df.groupby('Country')[['Cumulative_cases']].sum().reset_index()
# Out:
#                                                Country  Cumulative_cases
# 0                                          Afghanistan          35342895
# 1                                              Albania          51092192
# 2                                              Algeria          46151936
# 3                                       American Samoa            992033
# 4                                              Andorra           7046433
# ..                                                 ...               ...
# 235                                  Wallis and Futuna            378730
# 236                                              Yemen           2006422
# 237                                             Zambia          53676026
# 238                                           Zimbabwe          39671234
# 239  occupied Palestinian territory, including east...         112168647
#
# [240 rows x 2 columns]
